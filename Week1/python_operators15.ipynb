# %% [markdown]
# # Some type of operations
# Mathematical
# Comparison
# Logical

# %%
print(2+5)
print(5-3)
print(8*2)
print(10/2)
print(10//2)
print(10%3)
print(2**3)
print(5==5)
print(5!=6)
print(4>1)
print(3<8)
# Out:
# 7
# 2
# 16
# 5.0
# 5
# 1
# 8
# True
# True
# True
# True

# %%
print(True and False)
print (True or False)
print(not True)
# Out:
# False
# True
# False

# %%
x=10
x+=5
print(x)
# Out:
# 15

# %%
x-=4
print(x)
# Out:
# 11

# %%
x*=2
print(x)
# Out:
# 22

# %%
x/=4
print(x)
# Out:
# 1.375
